# %% [markdown]
# # Desafio em Grupo - mandacaru.dev

# %% [markdown]
# ## Cronograma
#
# **Semana 4 - 10/11 até 17/11**
# - Criação de Modelo
# - Criação de protótipo da aplicação web
# - Algoritmos de Classíficação:
#  - Breno:
#     - Random Forest
#  - Gardênia:
#     - Naive Bayes
#  - Julyanderson:
#     - SVM
#  - Murillo:
#     - Redes Neurais
#  - Vinicius:
#     - GBoosting
#     - XGBoosting
# **Semana 5 - 17/11 até 24/11**
# - Correção e melhora de modelo
# - Implementação da API REST
# **Semana 6 - 24/11 até 01/12**
# - Validação de resultados e testes estatísticos
# - Documentação
# **Semana 7 - 01/12 até 08/12**
# - Correções finais
# - Criação e treinamento da apresentação DemoDay
# **Última reunião - 08/12**
# **Entrega - 09/12**

# %% [markdown]
# ## Importando Bibliotecas

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# ## Carregando a base de dados

# %%
dataset = pd.read_csv('/content/sample_data/data.csv')

# %%
dataset
# Out:
#                                                Sentence Sentiment
# 0     The GeoSolutions technology will leverage Bene...  positive
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 3     According to the Finnish-Russian Chamber of Co...   neutral
# 4     The Swedish buyout firm has sold its remaining...   neutral
# ...                                                 ...       ...
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5838  Nordic Walking was first used as a summer trai...   neutral
# 5839  According shipping company Viking Line , the E...   neutral
# 5840  In the building and home improvement trade , s...   neutral
# 5841  HELSINKI AFX - KCI Konecranes said it has won ...  positive
#
# [5842 rows x 2 columns]

# %% [markdown]
# ## Explorando a base de dados

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5842 entries, 0 to 5841
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Sentence   5842 non-null   object
#  1   Sentiment  5842 non-null   object
# dtypes: object(2)
# memory usage: 91.4+ KB

# %%
dataset.describe()
# Out:
#                                                  Sentence Sentiment
# count                                                5842      5842
# unique                                               5322         3
# top     Managing Director 's comments : `` Net sales f...   neutral
# freq                                                    2      3130

# %%
dataset.isnull().values.any()
# Out:
# False

# %% [markdown]
# ## Tratando a base de dados

# %%
# removendo duplicatas
# dataset = dataset.drop_duplicates()
# dataset.head()

# %%
f# colocando tudo em minúsculo
dataset['clean_Sentence'] = dataset['Sentence'].str.lower()
dataset.head()
# Out:
#                                             Sentence Sentiment  \
# 0  The GeoSolutions technology will leverage Bene...  positive
# 1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2  For the last quarter of 2010 , Componenta 's n...  positive
# 3  According to the Finnish-Russian Chamber of Co...   neutral
# 4  The Swedish buyout firm has sold its remaining...   neutral
#
#                                       clean_Sentence
# 0  the geosolutions technology will leverage bene...
# 1  $esi on lows, down $1.50 to $2.50 bk a real po...
# 2  for the last quarter of 2010 , componenta 's n...
# 3  according to the finnish-russian chamber of co...
# 4  the swedish buyout firm has sold its remaining...

# %%
# removendo pontuação
dataset.loc[:,'clean_Sentence'] = dataset.loc[:,'clean_Sentence'].str.replace('[^\w\s]', '')
dataset.head()
# Out:
# <ipython-input-9-b8455c6ffa1b>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   dataset.loc[:,'clean_Sentence'] = dataset.loc[:,'clean_Sentence'].str.replace('[^\w\s]', '')
#                                             Sentence Sentiment  \
# 0  The GeoSolutions technology will leverage Bene...  positive
# 1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2  For the last quarter of 2010 , Componenta 's n...  positive
# 3  According to the Finnish-Russian Chamber of Co...   neutral
# 4  The Swedish buyout firm has sold its remaining...   neutral
#
#                                       clean_Sentence
# 0  the geosolutions technology will leverage bene...
# 1  esi on lows down 150 to 250 bk a real possibility
# 2  for the last quarter of 2010  componenta s net...
# 3  according to the finnishrussian chamber of com...
# 4  the swedish buyout firm has sold its remaining...

# %%
# removendo números
dataset.loc[:,'clean_Sentence'] = dataset.loc[:,'clean_Sentence'].str.replace('[0123456789]', '')
dataset.head()
# Out:
# <ipython-input-13-5f0792b1a95b>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   dataset.loc[:,'clean_Sentence'] = dataset.loc[:,'clean_Sentence'].str.replace('[0123456789]', '')
#                                             Sentence Sentiment  \
# 0  The GeoSolutions technology will leverage Bene...  positive
# 1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2  For the last quarter of 2010 , Componenta 's n...  positive
# 3  According to the Finnish-Russian Chamber of Co...   neutral
# 4  The Swedish buyout firm has sold its remaining...   neutral
#
#                                       clean_Sentence  \
# 0  geosolutions technology leverage benefon gps s...
# 1                     esi lows   bk real possibility
# 2  last quarter  componenta net sales doubled eur...
# 3  according finnishrussian chamber commerce majo...
# 4  swedish buyout firm sold remaining  percent st...
#
# ...

# %%
nltk.download('stopwords')
stop = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# removendo stopwords
dataset['clean_Sentence'] = dataset['clean_Sentence'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
dataset.head()
# Out:
#                                             Sentence Sentiment  \
# 0  The GeoSolutions technology will leverage Bene...  positive
# 1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2  For the last quarter of 2010 , Componenta 's n...  positive
# 3  According to the Finnish-Russian Chamber of Co...   neutral
# 4  The Swedish buyout firm has sold its remaining...   neutral
#
#                                       clean_Sentence  \
# 0  geosolutions technology leverage benefon gps s...
# 1                       esi lows bk real possibility
# 2  last quarter componenta net sales doubled eurm...
# 3  according finnishrussian chamber commerce majo...
# 4  swedish buyout firm sold remaining percent sta...
#
#                                         Sentence_tok
# 0  [geosolutions, technology, leverage, benefon, ...
# 1       [esi, lows, 150, 250, bk, real, possibility]
# 2  [last, quarter, 2010, componenta, net, sales, ...
# ...

# %%
# lematizando

# %%
# tokenizando
dataset['Sentence_tok'] = dataset['clean_Sentence'].str.split(' ')
dataset.head()
# Out:
#                                             Sentence Sentiment  \
# 0  The GeoSolutions technology will leverage Bene...  positive
# 1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2  For the last quarter of 2010 , Componenta 's n...  positive
# 3  According to the Finnish-Russian Chamber of Co...   neutral
# 4  The Swedish buyout firm has sold its remaining...   neutral
#
#                                       clean_Sentence  \
# 0  geosolutions technology leverage benefon gps s...
# 1                       esi lows bk real possibility
# 2  last quarter componenta net sales doubled eurm...
# 3  according finnishrussian chamber commerce majo...
# 4  swedish buyout firm sold remaining percent sta...
#
#                                         Sentence_tok
# 0  [geosolutions, technology, leverage, benefon, ...
# 1                 [esi, lows, bk, real, possibility]
# 2  [last, quarter, componenta, net, sales, double...
# ...
